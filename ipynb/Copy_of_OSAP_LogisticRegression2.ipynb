# %% [markdown]
# Expectation: A working solution where the learned class label using Logistic Regression is similar (for most possible points) to the training class label.
#
# Optional: Show the decision boundary. Note that it is not trivial to the draw the decision boundary in the examples below.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def plotClass(X,y,p):
    plt.figure()
    for i in range(y.shape[1]):
        if y[0,i]==0:
            plt.plot(X[0,i],X[1,i],'r'+p)
        else:
            plt.plot(X[0,i],X[1,i],'b'+p)
            
    plt.show()

# %%
#Q1
num_data=1000 # data points per class

X=np.random.uniform(-1,1,[2,num_data])**2
y=X[0,:]**2+X[1,:]**2-0.5>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a6aae50ba271> in <module>
#       2 num_data=1000 # data points per class
#       3
# ----> 4 X=np.random.uniform(-1,1,[2,num_data])**2
#       5 y=X[0,:]**2+X[1,:]**2-0.5>0
#       6 y=(y[None,:]).astype(np.int8)
#
# NameError: name 'np' is not defined

# %%
X = X.T
y = y.T

# %%
def sigmoid(z):
  return 1/(1+np.exp(-z))


def loss(yhat, y):
  return np.sum(-y*np.log(yhat) - (1-y)*np.log(1-yhat), axis =0)

# %%
M = 3
Xbig = []
for i in range(M+1):
  for j in range(M+1):
    Xbig.append(X[:,0]**i * X[:, 1]**j)


Xbig = np.array(Xbig).T

# %%
# w is theat
w = np.random.randn(Xbig.shape[1], 1) 
lr = 0.0001

ls = []
for i in range(1000):
  Z = Xbig@w
  yhat = sigmoid(Z)
  l = loss(yhat, y)

  dw = Xbig.T@ (yhat - y)
  w = w-lr*dw
  ls.append(l)


plotClass(X.T, y.T, 'o')
plt.figure()
plotClass(X.T, (yhat.T>0.5), 'x')

plt.figure()
plt.plot(ls)

# %%
Xbig.shape
# Out:
# (1000, 9)

# %%
#Q2
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])**2
y=X[0,:]**2-X[1,:]**2-3>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q3
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
x1= np.absolute(X)
y=5*x1[0,:]**2+0.5*x1[1,:]**2-20>0
y=(y[None,:]).astype(np.int8)
plotClass(x1,y,'o')
print(x1.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q4
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])**2
y=10*np.exp(-X[0,:]**2)+X[1,:]**2-7>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q5
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
y=X[0,2]-20*X[1,:]**3>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q6
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
y=X[0,2]*X[1,:]>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q7
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])%2
y=(np.floor(X[0,:]%2)==0)& (np.floor(X[1,:]%2)==0)>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)
