# %% [markdown]
# Expectation: A working solution where the learned functions (for each training dataset) using Linear Regression is close to the training data points.

# %%
#Linear Regression for general functions
import numpy as np
import matplotlib.pyplot as plt
import math
pi=math.pi


x=np.linspace(-1,1,100)

y=np.sin(2*pi*.5*x)+0.3*np.random.randn(x.size)
plt.plot(x,y, 'ro')

# %%
x.shape
# Out:
# (10,)

# %%
M = 10
X = []
for i in range(M+1):
  X.append(x**i)

X = np.array(X).T
print(X.shape)
# Out:
# (100, 11)

# %%
theta = np.linalg.solve(X.T@X, X.T@y)

yhat = X@theta

plt.plot(x,y,'o', x, yhat)
# Out:
# [<matplotlib.lines.Line2D at 0x7f5dfc3b2df0>,
#  <matplotlib.lines.Line2D at 0x7f5dfc3b2dc0>]

# %%
y.shape
# Out:
# (100,)

# %%
M = 3

X =[]

# for i in range(M+1):
#   X.append(x**i)

x = np.reshape(x, (100,1))
basis = np.arange(M+1)
basis = np.reshape(basis, (1, M+1))
X = x**basis

#X = np.array(X).T
print(X.shape)

# theat = inv(Xt X) (X.t y)
theta = np.linalg.inv(X.T @ X) @ (X.T @y)
#theta = np.linalg.solve(X.T @ X, X.T @y)

yhat = X@ theta

plt.plot(x,y,'bo', x, yhat)
# Out:
# (100, 4)
# [<matplotlib.lines.Line2D at 0x7ff147550250>,
#  <matplotlib.lines.Line2D at 0x7ff147550220>]

# %%
x0=np.linspace(0.1,1,100)

y0=np.log(x0)+0.1*np.random.randn(x0.size)
plt.plot(x0,y0,'ro')

# %%
x0=np.linspace(-1,1,20)

y0=np.cos(pi*x0)+0.3*np.random.randn(x0.size)
plt.plot(x0,y0,'ro')


xv=np.linspace(-1,1,10)

yv=np.cos(pi*xv)+0.3*np.random.randn(xv.size)
plt.plot(x0,y0,'ro', xv, yv,'gx')
# Out:
# [<matplotlib.lines.Line2D at 0x7f5dfc2a3ac0>,
#  <matplotlib.lines.Line2D at 0x7f5dfc2a3b80>]

# %%
error_val = []
error_train = []
for M in range(10):
  X = []
  for i in range(M+1):
    X.append(x0**i)

  X = np.array(X).T
  theta = np.linalg.solve(X.T@X, X.T@y0)
  Xval = []
  for i in range(M+1):
    Xval.append(xv**i)

  Xval = np.array(Xval).T
  yhat_val = Xval@theta
  error = np.sum((yv-yhat_val.squeeze())**2)
  error_val.append(error)
  print(error)
  yhat = X@theta
  error = np.sum((y0-yhat.squeeze())**2)
  error_train.append(error)
  plt.figure()
  plt.plot(x0,y0, 'ro', x0, yhat)


plt.figure()
plt.plot(error_train)
plt.plot(error_val)
# Out:
# 8.825671293300346
# 8.912585084288736
# 2.742425704450415
# 3.2569055899309527
# 2.260240518001672
# 2.1988870068823636
# 2.1931413438894536
# 2.1973863793309683
# 2.2458269103160746
# 2.4922946573476876

# %%
error_val= []
error_train = []
for M in range(1, 10):
  plt.figure()
  basis = np.arange(M+1)
  X = x0[:, np.newaxis]**basis[np.newaxis, :]
  print(X.shape)

  theta = np.linalg.solve(X.T@X, X.T@y0)
  yhat = X@theta

  plt.plot(x0,y0,'ro', xv, yv,'gx')
  plt.plot(x0,yhat)
  #val error
  Xv = xv[:, np.newaxis]**basis[np.newaxis, :]
  yhat_val = Xv@theta
  error = np.sum((yv-yhat_val)**2)
  error_t = np.sum((y0 - yhat)**2)


  error_val.append(error)
  error_train.append(error_t)



plt.figure()
plt.plot(error_val)   
plt.plot(error_train)
# Out:
# (20, 2)
# (20, 3)
# (20, 4)
# (20, 5)
# (20, 6)
# (20, 7)
# (20, 8)
# (20, 9)
# (20, 10)

# %%
x=np.linspace(-1,1,100)

y=x>0+0.1*np.random.randn(x.size)
plt.plot(x,y,'ro')

# %%
import numpy as np
x=np.linspace(-1,1,100)

y=x*np.sin(2*3.14*2*x)+0.1*np.random.randn(x.size)
plt.plot(x,y,'ro')

# %%
M = 9
X = []
for i in range(M+1):
  X.append(x**i)


X = np.array(X).T

theta = np.linalg.solve(X.T@X, X.T@y)
yhat = X@theta


plt.plot(x,y,'ro', x, yhat)
# Out:
# [<matplotlib.lines.Line2D at 0x7f5def04bfa0>,
#  <matplotlib.lines.Line2D at 0x7f5def04bf70>]

# %%
x=np.linspace(-1,1,100)

y=np.exp(-x**2)+0.1*np.random.randn(x.size)
plt.plot(x,y,'ro')

# %%
M = 5
basis = np.arange(M+1)
X = np.cos(0.5*pi*x.reshape(-1,1)*basis.reshape(1,-1))


theta = np.linalg.solve(X.T@X, X.T@y)
yhat = X@theta


plt.plot(x,y, 'ro', x, yhat)
# Out:
# [<matplotlib.lines.Line2D at 0x7f5deeb79fd0>,
#  <matplotlib.lines.Line2D at 0x7f5deeb79fa0>]

# %%
M = 5
basis = np.arange(M+1)
X = np.exp(-(x.reshape(-1,1)-basis.reshape(1,-1))**2)


theta = np.linalg.solve(X.T@X, X.T@y)
yhat = X@theta


plt.plot(x,y, 'ro', x, yhat)
# Out:
# [<matplotlib.lines.Line2D at 0x7f5deeaec6a0>,
#  <matplotlib.lines.Line2D at 0x7f5deeaec670>]

# %%
M = 7
basis = np.arange(M+1)
X = x.reshape(-1,1) ** basis.reshape(1,-1)


theta = np.linalg.solve(X.T@X, X.T @y)

yhat = X@theta
plt.plot(x,y, 'ro', x,yhat)

print(X.shape)
# Out:
# (100, 8)
